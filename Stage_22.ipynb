# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
clean_data = pd.read_csv('cleaned_data22.csv')

# %%
clean_data.head()
# Out:
#    Height  Weight  Age  Grip Strength Frailty  Grip Strength (Pound)
# 0    65.8     112   30             30       N               66.13860
# 1    71.5     136   19             31       N               68.34322
# 2    69.4     153   45             29       N               63.93398
# 3    68.2     142   22             28       N               61.72936
# 4    67.8     144   29             24       Y               52.91088

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Height                 10 non-null     float64
#  1   Weight                 10 non-null     int64
#  2   Age                    10 non-null     int64
#  3   Grip Strength          10 non-null     int64
#  4   Frailty                10 non-null     object
#  5   Grip Strength (Pound)  10 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 608.0+ bytes

# %%
clean_data.describe()
# Out:
#           Height      Weight        Age  Grip Strength  Grip Strength (Pound)
# count  10.000000   10.000000  10.000000      10.000000              10.000000
# mean   68.600000  131.900000  32.500000      26.000000              57.320120
# std     1.670662   14.231811  12.860361       4.521553               9.968307
# min    65.800000  112.000000  17.000000      19.000000              41.887780
# 25%    67.825000  120.750000  22.250000      22.500000              49.603950
# 50%    68.450000  136.000000  29.500000      27.000000              59.524740
# 75%    69.700000  141.750000  43.500000      29.750000              65.587445
# max    71.500000  153.000000  51.000000      31.000000              68.343220

# %%
sns.histplot(clean_data['Grip Strength'], bins = 10 , kde = True)
# Out:
# <Axes: xlabel='Grip Strength', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
x= clean_data['Age']
y1= clean_data['Grip Strength (Pound)']
y2= clean_data['Weight']
plt.plot(x, y1, label ='y1')
plt.plot(x, y2, '-.', label ='y2')
