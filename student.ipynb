# %%
import pandas as pd

# %%
raw_data = pd.read_csv("StudentsPerformance.csv")

# %%
raw_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
raw_data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
raw_data.drop_duplicates(inplace = True)

# %%
raw_data["Average score"] = (raw_data["math score"]+raw_data["reading score"]+ raw_data["writing score"])/3

# %%
raw_data.to_csv("cleaned_data.csv" , index=False)

# %%
clean_data = pd.read_csv("cleaned_data.csv")

# %%
clean_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Average score
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
# ...

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='parental level of education', y='math score', data=clean_data, palette='Set3')
plt.xlabel('parental level of education')
plt.ylabel('math Score')
plt.title('Box Plot of gender vs math Score')
plt.xticks(rotation=45, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
ax = sns.countplot(y="race/ethnicity" , hue="test preparation course" , data = clean_data)
graph = ax.get_figure()

# %%
scores = sns.scatterplot(data = clean_data , x='lunch' , y = 'Average score')
graph=scores.get_figure()

# %%
clean_data['test preparation course'] = clean_data['test preparation course'].map({'completed' : 1 , 'none' : 0})
correlation_matrix = clean_data[['test preparation course','Average score']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap of test preparation course vs. Average score')
plt.savefig('visualizations\correlation_matrix_heatmap.png', bbox_inches='tight')
plt.show()

# %%
gender = clean_data['gender']
Average_scores = clean_data['Average score']

plt.figure(figsize=(10, 6))
clean_data_grouped = clean_data.groupby('gender')['Average score'].mean()
clean_data_grouped.plot(kind='bar', color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Average score')
plt.title('Bar Chart of Gender vs. Average Score')
plt.xticks(rotation=0)

plt.savefig('visualizations\\bar_chart.png', bbox_inches='tight')

plt.show()
